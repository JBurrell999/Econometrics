# %%
(1+1)**2
# Out:
# 4

# %%
(3*4)/(5*6)
# Out:
# 0.4

# %%
4**(1/2)*(3-2)
# Out:
# 2.0

# %%
my_List = [5,8,4,5,6,2]
my_List.sort()
print(my_List)
# Out:
# [2, 4, 5, 5, 6, 8]

# %%
my_List[0:1]
print(my_List)
# Out:
# [2, 4, 5, 5, 6, 8]

# %%
my_List[1:-1]
# Out:
# [4, 5, 5, 6]

# %%
some_list = [1,2]
print()

# %%
some_list[0] = 3
print(some_list)
# Out:
# [3, 2]

# %%
some_list.append(4)

# %%
for i in range(len(some_list)):
    print(some_list[i]+1)
# Out:
# 4
# 3
# 5

# %%
len(some_list)
# Out:
# 3
