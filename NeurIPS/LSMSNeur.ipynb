# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier  # ✅ CPU RF
from sklearn.model_selection import GroupKFold, ParameterGrid
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import accuracy_score, f1_score                      # ✅ for classifiers
from tqdm.notebook import tqdm
import joblib
from time import perf_counter
import xgboost as xgb                                                     # ✅ XGBoost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier  # ✅ CPU RF
#       5 from sklearn.model_selection import GroupKFold, ParameterGrid
#       6 from sklearn.metrics import r2_score, mean_squared_error
#
# ModuleNotFoundError: No module named 'sklearn'
