# %%
import pandas as pd

df = pd.read_stata("/Users/jjburrell/Downloads/Plot_dataset.dta")
# Out:
# /var/folders/kh/hkkfd68s6mb8b11z27mn1b4h0000gn/T/ipykernel_84831/3401052331.py:3: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata("/Users/jjburrell/Downloads/Plot_dataset.dta")

# %%
df.columns
# Out:
# Index(['country', 'wave', 'hh_id_obs', 'hh_id_merge', 'plot_id_obs',
#        'plot_id_merge', 'parcel_id_obs', 'parcel_id_merge', 'season', 'pw',
#        ...
#        'rooting_conditions', 'oxygen_availability', 'excess_salts', 'toxicity',
#        'workability', 'soil_fertility_index', 'plot_dist_household',
#        'plot_slope', 'main_crop', 'plot_area_GPS_1_'],
#       dtype='object', length=115)

# %%
df2 = pd.read_csv("/Users/jjburrell/Downloads/EE_harvest_ml.csv")

# %%
df2.head()
# Out:
#     country  wave  season  lat_modified  lon_modified  EVI_max_0  EVI_max_1  \
# 0  Ethiopia   1.0     1.0      3.455701     39.515994   0.231461   0.418776
# 1  Ethiopia   1.0     1.0      3.549937     39.184234   0.222820   0.437053
# 2  Ethiopia   1.0     1.0      5.299477     37.482618   0.203718   0.350867
# 3  Ethiopia   1.0     1.0      5.495345     37.551843   0.285929   0.354751
# 4  Ethiopia   1.0     1.0      5.525706     38.762067   0.497398   0.437111
#
#    EVI_max_10  EVI_max_11  EVI_max_2  ...  temperature_2m_min_mean_10  \
# 0    0.111361    0.090664   0.406541  ...                  295.366704
# 1    0.108189    0.091194   0.263618  ...                  295.510766
# 2    0.191025    0.152042   0.266320  ...                  294.573792
# 3    0.159949    0.150882   0.407114  ...                  293.970703
# 4    0.184748    0.267662        NaN  ...                  286.848131
#
#    temperature_2m_min_mean_11  temperature_2m_min_mean_2  \
# ...
