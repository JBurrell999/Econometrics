# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/jjburrell/Downloads/school_data.csv")

# %%
df.describe().T
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   v1                    467 non-null    int64
#  1   schoolid              467 non-null    int64
#  2   schoolname            467 non-null    object
#  3   submissiondate        467 non-null    object
#  4   district              467 non-null    object
#  5   householdincome2005   467 non-null    float64
#  6   householdincome2015   467 non-null    float64
#  7   curriculumchange1     467 non-null    object
#  8   curriculumchange2     174 non-null    object
#  9   curriculumchange3     63 non-null     object
#  10  mathematicsscore2000  467 non-null    int64
#  11  mathematicsscore2001  467 non-null    int64
#  12  mathematicsscore2002  467 non-null    int64
#  13  mathematicsscore2003  467 non-null    int64
#  14  mathematicsscore2004  467 non-null    int64
# ...

# %%
df.isna()
# Out:
#         v1  schoolid  ...  mathematicsscore2019  districtcode
# 0    False     False  ...                 False         False
# 1    False     False  ...                 False         False
# 2    False     False  ...                 False         False
# 3    False     False  ...                 False         False
# 4    False     False  ...                 False         False
# ..     ...       ...  ...                   ...           ...
# 462  False     False  ...                 False         False
# 463  False     False  ...                 False         False
# 464  False     False  ...                 False         False
# 465  False     False  ...                 False         False
# 466  False     False  ...                 False         False
#
# [467 rows x 31 columns]

# %%
df = df.drop(index=('householdincome2005', ))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = df.drop(index=('householdincome2005' <= '20000'))
#
# File ~/Econometrics/Econometrics/.venv/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df['district']
# Out:
# 0            Cross Roads Independent School District
# 1                Wheeler Independent School District
# 2                   Terlingua Common School District
# 3            Cross Roads Independent School District
# 4      Round Top-Carmine Independent School District
#                            ...
# 462    Round Top-Carmine Independent School District
# 463                 Hart Independent School District
# 464               Gruver Independent School District
# 465              Wheeler Independent School District
# 466              Wheeler Independent School District
# Name: district, Length: 467, dtype: object

# %%
inddist = []
df = df[['district', 'householdincome2005']].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = df[['district', 'householdincome2005']].mean()
#
# File ~/Econometrics/Econometrics/.venv/lib/python3.13/site-packages/pandas/core/frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)  11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~/Econometrics/Econometrics/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
# ...

# %%
df[df['district'] == 'Hart Independent School District'].describe()

#df[['Hart Independent School District']].describe()
#df[['district', 'districtcode']].value_counts
# Out:
#               v1      schoolid  ...  mathematicsscore2019  districtcode
# count  115.00000  1.150000e+02  ...            115.000000    115.000000
# mean   215.00000  3.943827e+06  ...            586.156522      2.947826
# std    128.07317  1.261382e+06  ...            179.445764      0.223351
# min      8.00000  2.474000e+04  ...            156.000000      2.000000
# 25%    107.50000  3.419354e+06  ...            474.500000      3.000000
# 50%    211.00000  4.149968e+06  ...            604.000000      3.000000
# 75%    312.50000  4.626218e+06  ...            699.000000      3.000000
# max    463.00000  5.791580e+06  ...            999.000000      3.000000
#
# [8 rows x 25 columns]

# %%
import model.ols 
    math
