# %% [markdown]
# # Computational Economics — Comprehensive Midterm Study Guide
#
# **Generated:** 2025-10-29 18:08
# **Based on:** Completed lecture notes and problem sets (Lectures 2–5, PS1, PS2).
#
# This guide is designed for open-note preparation. It includes conceptual reviews, key formulas, clean code examples, practice problems (with variants), and short worked solutions.

# %% [markdown]
# ## Lecture 2 — Numerical Methods & Optimization
# _Source: `lecture2`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# If you have ever used MATLAB, you probably know that doing matrix operations is possible using loops but it is extremely slow! In Python, Numpy gives you MATLAB like operations that are much faster than loops.
# NumPy is a Python library or module.
# A module is just a bunch of code you import into your workspace.
# Generally, imports go at the top of your notebook/script, but you just need it before using particular function/method from that module.
# (The line %matplotlib inline is a Jupyter notebook "magic" function that renders plots inside the notebook.)
# We can now access the many NumPy functions by typing np.function() . Ditto Matplotlib.
# Let's start with the core NumPy product -- the array.
# We know we can make lists in Python:
# What if we want to add one to each element?
# We know this doesn't work:
# Instead we have to write a loop:
# NumPy helps us avoid writing loops to do basic tasks.
# How? By using NumPy arrays.
# You create an array with the function np.array() .
# (The .array() syntax means the function is a method from the NumPy module.)

# %% [markdown]
# ### Key Equations / Principles
# - NumPy ¶
# - Modules ¶
# - NumPy arrays ¶
# - Vectorization ¶
# - Vectorized math ¶
# - Math Excersises ¶
# - Vectorized comparisons ¶
# - Random numbers ¶
# - Normal Distribution ¶
# - Uniform distribution ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
# We will import the NumPy module -- and the Matplotlib module to make basic plots.
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# make some_list of 1,2,3

some_list = [1, 2, 3]
some_list

# %%
[1, 2, 3]

# %%
# add one to some_list

some_list + 1

# %%
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
Input In [42], in <cell line: 3>()
      1 # add one to some_list
----> 3 some_list + 1

TypeError: can only concatenate list (not "int") to list

# %%
# add one with list comprehension

some_list = [x+1 for x in some_list]

some_list

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **NumPy ¶** in Numerical Methods & Optimization.
# 2. (b) Write a Python implementation of NumPy ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where NumPy ¶ would fail or require modification.
# 4. (a) Explain the principle of **Modules ¶** in Numerical Methods & Optimization.
# 5. (b) Write a Python implementation of Modules ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Modules ¶ would fail or require modification.
# 7. (a) Explain the principle of **NumPy arrays ¶** in Numerical Methods & Optimization.
# 8. (b) Write a Python implementation of NumPy arrays ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where NumPy arrays ¶ would fail or require modification.
# 10. (a) Explain the principle of **Vectorization ¶** in Numerical Methods & Optimization.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Bisection relies on the Intermediate Value Theorem; ensures convergence under sign change. Newton converges quadratically near the root if derivative nonzero.
# - For optimization, show example using `scipy.optimize.minimize`; interpret gradient norm and stopping condition.

# %% [markdown]
# ## Lecture 3 — Linear Models & OLS
# _Source: `lecture3`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# Pandas is a Python package for user-friendly, fast and easy data analysis and manipulation. Pandas provides a set of data structures which include Series, DataFrames and Panels. Series are the equivalent of 1-dimensional arrays. DataFrames are collections of Series and so are 2-dimensional. Panels are collections of DataFrames, and have 3 dimensions.
# Series are the primary building block of the data structures in pandas, and in many ways a Series behaves similarly to a NumPy array.
# Notice:
# - An index for each value was created and the index defaulted to start with 0.
# - The value of 9 in the list was converted into a float. Why did this happened?
# - The data type of the series is indicated. Pandas uses NumPy to efficiently represent data in memory. As such, all the values of the series must be of the same data type.
# A Series can be initialized using a list, tuple, directly from a NumPy array or using a
# dictionary.
# The index is an important property of the pandas’s data structures (Series and DataFrame). It allows for dictionary-like access using values in the index (in addition to both numeric slicing and logical indices).
# Math operations involving two series operate by aligning indices. The mathematical operation is performed
# in two steps. First, the union of all indices is created, and then the mathematical operation is performed on
# matching indices. Indices that do not match are given the value NaN (not a number), and values are computed
# for all unique pairs of repeated indices.
# Important properties and methods:
# Very useful: We can use bracket notation to access elements of series but it is not recomended. It is better to use loc and iloc
# Why are we getting error? Because, pandas is trying to find element with index 0, which does not exists. To access elements we can use iloc or loc.
# While the Series class is the building block of data structures in pandas, the DataFrame is the work-horse.
# DataFrames collect multiple series in the same way that a spreadsheet collects multiple columns of data. In
# a simple sense, a DataFrame is like a 2-dimensional NumPy array – and when all data is numeric and of the
# same type (e.g. float64), it is virtually indistinguishable. However, a DataFrame is composed of Series and
# each Series has its own data type, and so not all DataFrames are representable as homogeneous NumPy arrays.
# Like Series, there are a few ways to initialize pandas DataFrame
# important rules for slicing: if you use loc, you should provide "names" of index and column, but if you use
# iloc you should provide locations for both index and column

# %% [markdown]
# ### Key Equations / Principles
# - Pandas ¶
# - Pandas Series ¶
# - Pandas DataFrame ¶
# - Summary (Panda) ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
import pandas as pd

#initialize pandas series with values 0.1, 1.2, 2.3, 3.4, 9

s=pd.Series([0.1, 1.2, 2.3, 3.4, 9])

s

# %%
0    0.1
1    1.2
2    2.3
3    3.4
4    9.0
dtype: float64

# %%
import numpy as np

# create numpy array
a=np.array([0.1, 1.2, 2.3, 3.4, 9])

# use numpy array a to initialize pandas Series
s=pd.Series(a)
s

# %%
0    0.1
1    1.2
2    2.3
3    3.4
4    9.0
dtype: float64

# %%
# Series index need not be integers:

# use the same array as above and initialize pandas series with indexes "a", "b"...

s = pd.Series(a, index=['a', 'b', 'c', 'd', 'e'])
s

# %%
a    0.1
b    1.2
c    2.3
d    3.4
e    9.0
dtype: float64

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **Pandas ¶** in Linear Models & OLS.
# 2. (b) Write a Python implementation of Pandas ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where Pandas ¶ would fail or require modification.
# 4. (a) Explain the principle of **Pandas Series ¶** in Linear Models & OLS.
# 5. (b) Write a Python implementation of Pandas Series ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Pandas Series ¶ would fail or require modification.
# 7. (a) Explain the principle of **Pandas DataFrame ¶** in Linear Models & OLS.
# 8. (b) Write a Python implementation of Pandas DataFrame ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where Pandas DataFrame ¶ would fail or require modification.
# 10. (a) Explain the principle of **Summary (Panda) ¶** in Linear Models & OLS.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Derive OLS estimator $\hat\beta=(X^TX)^{-1}X^Ty$. Confirm equivalence to least-squares minimization. Use `np.linalg.lstsq` for numerical stability.
# - Interpret β coefficients as marginal effects; inspect residual variance and $R^2$.

# %% [markdown]
# ## Lecture 4 — Agent-Based Modeling
# _Source: `lecture4_class`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# Many problems in economics requre solving set of linear equaions or optimizing set of linear objective functions. In both, we need to have a good understanding of matrix algebra.
# In this lecture:
# - Discuss vector and matrix operations
# - Show how to solve set of linear equations using Python
# - Show how to perform constrained optimization of linear objective function using Python
# Vector in general is defined as a quantity having direction as well as magnitude. But for the purpose of this course we refer a vector to be sequence of numbers. For example [1, 2, 40, 3] is a vector with length 4. When programming, we can use list, numpy array, or pandas series to represent vector. There are few operations that we need to know.
# - Vector addition : if we have two vectors $a$ and $b$ of length $n$ (we will write this as $a, b \in \mathbb{R}^n$), we can add them element by element:
# - Scalar multiplication : if we have a vector $a\in \mathbb{R}^n$ and scalar $\theta\in \mathbb{R}$:
# - Inner (dot) product : the inner product of two vectors is a measure of how aligned they are. Mathematically, if $a, b \in \mathbb{R}^n$, inner product is calculated as:
# We denote transpose by $T$ or by $'$. Traspose is operation that flips given matrix (or vector in this case) by making rows as columns and columns as rows.
# - Norm : is a length of a vector. There are few ways people calculate it but the most popular (and intuative) is euclidean norm (also called L2 norm). If we have a vector $a\in \mathbb{R}^n$:
# Let's do some numerical examples. As we already know, in python the best list type structure for numerical operations is numpy array. Therfore, when it comes to vector operations, more often than not we will be using numpy arrays.
# In mathematics, a matrix is a rectangular array or table of numbers , symbols, or expressions, arranged in rows and columns. This means that if in case of vector we have only one subscript. Now, we have two subscripts, one inicating the row and another indicating the column. For example matrix of size $n \times m$ will look something like this:
# We say element $x_{ij}$ is an element of $X$ which is located at the interection of $i^{th}$ row and $j^{th}$ column.
# Scalar maltiplication and addition (matrix to matrix addition) works the same way as in case of vectors so we don't need to spend any time on that. Let's discuss matrix multiplication. It is kind of extension of inner product discussed above.

# %% [markdown]
# ### Key Equations / Principles
# - Linear Algebra and Linear Programming ¶
# - Vector Operations ¶
# - Matrix Operations ¶
# - Solving linear equations ¶
# - Linear optimization problems ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
# import numpy

import numpy as np

# %%
# generate two vectors of length 5 called a~N(0, 2) and b~U(-1, 1)

a = np.random.normal(0, 2, 5)
b = np.random.uniform(-1, 1, 5)

print(a)
print(b)

# %%
[ 3.09382104  1.64185767  1.7207527   1.42034969 -0.71881822]
[ 0.58434608 -0.29491487  0.05199724 -0.69656753  0.58848625]

# %%
# add a and b

a+b

# %%
array([ 3.67816712,  1.3469428 ,  1.77274994,  0.72378216, -0.13033197])

# %%
# multiply a on 2
2*a

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **Linear Algebra and Linear Programming ¶** in Agent-Based Modeling.
# 2. (b) Write a Python implementation of Linear Algebra and Linear Programming ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where Linear Algebra and Linear Programming ¶ would fail or require modification.
# 4. (a) Explain the principle of **Vector Operations ¶** in Agent-Based Modeling.
# 5. (b) Write a Python implementation of Vector Operations ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Vector Operations ¶ would fail or require modification.
# 7. (a) Explain the principle of **Matrix Operations ¶** in Agent-Based Modeling.
# 8. (b) Write a Python implementation of Matrix Operations ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where Matrix Operations ¶ would fail or require modification.
# 10. (a) Explain the principle of **Solving linear equations ¶** in Agent-Based Modeling.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Each agent follows update rule $s_{t+1}=(1-\alpha)s_t+\epsilon_t$. Aggregate outcomes emerge from individual dynamics.
# - Vary α to test stability; low α = fast decay, high α = persistence.

# %% [markdown]
# ## Lecture 5 — Discrete Choice / Logit
# _Source: `lecture5_working`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# In economics we use a lot of different mathematical models to describe enviroments. We already discussed simple two good supply-demand model and found a computational way we can solve for equilibrium. In this lecture we discuss 3 other simple economic models and computational solutions. I selected those three models mainly because, they are very different from each other, so it will help us cover a wide range of models.
# I borrow all three models from QuantEcon project!
# A mutual fund has $100 000 to invest over three year horizon. There are three investment options.
# - Annuity: Fund can invest the same amount at the begining of years 1, 2, and 3 and get 130% return at the end of year 3 of total capital.
# - Bank account: Fund can invest any amount at the begining of each year to get capital plus 6% return at the end of each year. They can also borrow $20 000 at the begining of each year to pay back back borrowed amount plus 6% at the end of the year.
# - Corporate bond: from year 2, a corporate bond becomes available and the fund can invest no more than $50 000. In fund invests, they will get 130% at the end of the third year.
# Obviously, the mutual fund wants to maximize total payout. Let's reframe this as linear programming problem.
# Decision variables:
# - $x_1$: amount to put in annuity (in every year)
# - $x_2$, $x_3$, $x_4$: bank balances at the begining of each year, if negative indicates borrowing.
# - $x_5$: the corporate bond investment
# Table below describes timeline of each investment.
# Let's write down mutual funds optimization problem.
# The objective functions:
# - Fund invests $3x_1$ in annuity to get $1.30\cdot 3x_1$

# %% [markdown]
# ### Key Equations / Principles
# - Simple Models in Economics ¶
# - Example 1: Investment Problem ¶
# - Schelling’s Segregation Model ¶
# - Shortest Paths ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
# import modules

import numpy as np
import pandas as pd

from scipy.optimize import linprog
import matplotlib.pyplot as plt

# %%
# Objective function parameters
c_ex2 = np.array([1.30*3, 0, 0, 1.06, 1.30])

# equality constraints
A_ex2 = np.array([[1,  1,  0,  0,  0],
                  [1, -1.06, 1, 0, 1],
                  [1, 0, -1.06, 1, 0]])
b_ex2 = np.array([100000, 0, 0])

# Bounds on decision variables
bounds_ex2 = [(  0,    None),
              (-20000, None),
              (-20000, None),
              (-20000, None),
              (  0,   50000)]

# Solve the problem
res_ex2 = linprog(-c_ex2, A_eq=A_ex2, b_eq=b_ex2, bounds=bounds_ex2)

res_ex2

# %%
        message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
        success: True
         status: 0
            fun: -141018.24349792692
              x: [ 2.493e+04  7.507e+04  4.649e+03 -2.000e+04  5.000e+04]
            nit: 0
          lower:  residual: [ 2.493e+04  9.507e+04  2.465e+04  0.000e+00
                              5.000e+04]
                 marginals: [ 0.000e+00  0.000e+00  0.000e+00  1.650e-01
                              0.000e+00]
          upper:  residual: [       inf        inf        inf        inf
                              0.000e+00]
                 marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
                             -1.470e-03]
          eqlin:  residual: [ 0.000e+00  0.000e+00  0.000e+00]
                 marginals: [-1.376e+00 -1.299e+00 -1.225e+00]
        ineqlin:  residual: []
                 marginals: []
 mip_node_count: 0
 mip_dual_bound: 0.0
        mip_gap: 0.0

# %%
# Draw from bivariate random uniform, and namne columns as 'x' and 'y'

agents = pd.DataFrame(np.random.uniform(0, 1, size = (500, 2)), columns=['x', 'y'])

# Since all the agents are randomly allocated at first, let's say the first 250 are orange and the last 250 green.
# We know that, computationally, integer is more memorry efficient than string, so insted of creating column
# something like agent's color, we create, a column 'orange' which equals 1 if the agent is orange and 0 if green
agents['orange']=1
agents.loc[250:, 'orange']=0

agents.head()

# %%
# we use scatterplot to show them on unit square

plt.scatter(agents[agents['orange']==1]['x'], agents[agents['orange']==1]['y'], color = 'orange')
plt.scatter(agents[agents['orange']==0]['x'], agents[agents['orange']==0]['y'], color = 'green')

plt.show()

# %%
# We will use the "while" loop to achove our goal.

# the get while loop started we need some "True" conditio and to end the same while loop, the same condition
# should change to false at some point. To achive that we create variable outside the loop and make sure
# it is true first and keep updating it in each iteration.

# We define two variables, unhappy. The while loop will run until at least one person is unhappy.
# So let's assign initial value to unhappy = 1 (it could be anythin as long as it satisfies while loop)
unhappy=1

# In order to count how many iterations it takes to converge (nobody to be willing to move) we also define iteration
# as zero and increae this nunmber by one each time while loop happens
iteration = 0

# as we said, in order to get the while loop started, the initial condition should be true. By initial assignment
# unhappy=1 so  it is > 0:

while unhappy>0:
    # create a placeholder where we store all the agents that moved.
    moved=[]

    # to keep the original data unafected until all the agents decide to move or not in each iteration
    # we make a copy of it
    agents_temp=agents.copy()

    # now we loop over each agent to see if they want to move or not
    for agent in agents.index.tolist():

        # their moving decision depends on number of similar types aroud the agent. We calculate distance manually
        # one step at a time, but you can put all in one line

        # first calculate elementwise difference between the given agents lication and everyone esle
        diff = agents_temp[['x', 'y']]-agents_temp.loc[agent, ['x', 'y']]

        # square each coordinate difference
        sq_diff = diff**2

        # sum squares of differences
        sum_sq_diff = sq_diff.sum(axis=1)

        # take  a square toot from the sum
        sqrt_sum_sq_diff = sum_sq_diff**0.5

        # in the temporary dataframe add a column which containes distance between a given agent and everyone else
        # includine the agent hersels (the distance between agent and herself should be zero)
        agents_temp['sqrt_sum_sq_diff']=sqrt_sum_sq_diff

        # Now we use little trick. After we sort the data by distance, we need to find if at least
        # five neighbors are similar type. In the sorted version, the closest agent will be, agent herself.
        # So we need to look at closes agents from the second closes to 10th closess, which in python will be [1:11].
        # We compare type of the given agent to all of them. If types coincide we get True, if not we get False
        # for python True is 1 and False is 0. If we sum this True-False values (of length 10),
        # we can get any number from 0 (in this case all the neighbors are other type) to
        # 10 (in this case all the neighbors are the same type)
        # The agent will be unhappy if less then five are the same type, so the agent is unhappy if the number is <5.

        if sum(agents_temp.sort_values(by='sqrt_sum_sq_diff')['orange'][1:11]==agents_temp.loc[agent, 'orange'])<5:
            # if the condition is met, the agent is unhappy and moves.
            # We will append list "moved" where we store all the agents who moved in a given iteration
            moved.append(agent)

            # Since the agent moves we will update her location in the original(!!!) data not in the copied version!
            agents.loc[agent, ['x', 'y']]=np.random.uniform(0, 1, size = (1, 2))[0]

    # After we check every agent, we find how many people where unhappy and if number is more than 0 while loop continues
    unhappy=len(moved)

    # At this point the iteration is done and we increase it by one to keep the record of how many iterations we are doing
    iteration += 1

    # to keep infromation coming at every iteration we print out what is happening in our code
    print('On iteration: '+str(iteration)+': '+str(len(moved))+' agets moved')

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **Simple Models in Economics ¶** in Discrete Choice / Logit.
# 2. (b) Write a Python implementation of Simple Models in Economics ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where Simple Models in Economics ¶ would fail or require modification.
# 4. (a) Explain the principle of **Example 1: Investment Problem ¶** in Discrete Choice / Logit.
# 5. (b) Write a Python implementation of Example 1: Investment Problem ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Example 1: Investment Problem ¶ would fail or require modification.
# 7. (a) Explain the principle of **Schelling’s Segregation Model ¶** in Discrete Choice / Logit.
# 8. (b) Write a Python implementation of Schelling’s Segregation Model ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where Schelling’s Segregation Model ¶ would fail or require modification.
# 10. (a) Explain the principle of **Shortest Paths ¶** in Discrete Choice / Logit.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Logit model derives from Gumbel errors → softmax probabilities. Use `scipy.special.softmax` for numeric stability.
# - Estimation via log-likelihood maximization: $\ell(\beta)=\sum y_{ij}\log P_{ij}$; interpret parameters as relative utilities.

# %% [markdown]
# ## Problem Set 1 — Completed
# _Source: `PS1_class`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# - Add your name above
# - Fill in the empty chunks with your code.
# - Do not add any code chunks in your final submission besides the ones already here.
# - Use no additional modules.
# - You must submit your answers on canvas in HTML format !!!
# Create a list called x_values that contains first 100 integers in steps of 4
# Write three loops that cubes each element of x_values :
# - using explicit indexing
# - using implicit indexing
# - using list comprehension
# Write a function called cool_sum which takes two arguments and performs opperations as follows:
# - If both arguments are lists append the first list with the second list, for example if arguments are [1, 2, 3] and [4, 5], the functions should output [1, 2, 3, 4, 5]
# - If both arguments are numbers (integers or floats) perform standard summation, for example if arguments are 2 and 3.4 the output should be 5.4
# - If one of the arguments is list and another number (integer or float) add that number to each element of the list, for example if arguments are [1, 2, 3] and 5 the output should be [6, 7, 8]
# - If either of the argument is neither list nor number print "Error: something unexpected happend"

# %% [markdown]
# ### Key Equations / Principles
# - Name: ¶
# - Instructions ¶
# - Basic Python: ¶
# - Question 1.1 ¶
# - Question 1.2 ¶
# - Question 1.3 ¶
# - Numpy ¶
# - Question 2.1 ¶
# - Question 2.2 ¶
# - Pandas ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
# creae x_list

x_values  = list(range(0, 100, 4))
x_values

# %%
[0,
 4,
 8,
 12,
 16,
 20,
 24,
 28,
 32,
 36,
 40,
 44,
 48,
 52,
 56,
 60,
 64,
 68,
 72,
 76,
 80,
 84,
 88,
 92,
 96]

# %%
# explicit indexing
s = []

for i in range(len(x_values)):
    s.append(x_values[i]**3)
s

# %%
[0,
 64,
 512,
 1728,
 4096,
 8000,
 13824,
 21952,
 32768,
 46656,
 64000,
 85184,
 110592,
 140608,
 175616,
 216000,
 262144,
 314432,
 373248,
 438976,
 512000,
 592704,
 681472,
 778688,
 884736]

# %%
# implicit indexing

s = []

for x in x_values:
    s.append(x**3)
s

# %%
[0,
 64,
 512,
 1728,
 4096,
 8000,
 13824,
 21952,
 32768,
 46656,
 64000,
 85184,
 110592,
 140608,
 175616,
 216000,
 262144,
 314432,
 373248,
 438976,
 512000,
 592704,
 681472,
 778688,
 884736]

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **Name: ¶** in Completed.
# 2. (b) Write a Python implementation of Name: ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where Name: ¶ would fail or require modification.
# 4. (a) Explain the principle of **Instructions ¶** in Completed.
# 5. (b) Write a Python implementation of Instructions ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Instructions ¶ would fail or require modification.
# 7. (a) Explain the principle of **Basic Python: ¶** in Completed.
# 8. (b) Write a Python implementation of Basic Python: ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where Basic Python: ¶ would fail or require modification.
# 10. (a) Explain the principle of **Question 1.1 ¶** in Completed.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Map each question to optimization routine or regression. Include convergence, tolerance, and result validation. Discuss assumptions and possible improvements.

# %% [markdown]
# ## Problem Set 2 — Completed
# _Source: `PS2_working`_

# %% [markdown]
# ### Conceptual Overview
# Below are core ideas, mechanisms, and takeaways consolidated from your completed notes. These summaries are rephrased for clarity and completeness.

# %% [markdown]
# - Add your name above
# - Fill in the empty chunks with your code.
# - Do not add any code chunks in your final submission besides the ones already here.
# - Use no additional modules.
# - You must submit your answers on canvas in HTML format !!!
# A hedge fund has \$150,000 to invest over a four-year horizon. There are four investment options available:
# - Annuity: The fund can invest the same amount at the beginning of years 1, 2, 3, and 4, and receive 140\% return on the total capital at the end of year 4. This option has restriction, if you invest any amount in year 1, you must invest the same amount in every year after that!
# Annuity: The fund can invest the same amount at the beginning of years 1, 2, 3, and 4, and receive 140\% return on the total capital at the end of year 4. This option has restriction, if you invest any amount in year 1, you must invest the same amount in every year after that!
# - Savings Account: The fund can invest any amount at the beginning of each year to receive the capital plus 5\% return at the end of each year. They can also borrow up to \$25,000 at the beginning of each year, to be repaid with 5\% interest at the end of the year.
# Savings Account: The fund can invest any amount at the beginning of each year to receive the capital plus 5\% return at the end of each year. They can also borrow up to \$25,000 at the beginning of each year, to be repaid with 5\% interest at the end of the year.
# - Tech Startup Investment: At the start of the year 2, an opportunity to invest in a promising tech startup becomes available. The fund can invest up to \$75,000 in this option. If they choose to invest, they will receive the invested capital plus 150\% return at the end of the fourth year. (Notice, here you get not 150\% in total but invested capital PLUS 150\% return).
# Tech Startup Investment: At the start of the year 2, an opportunity to invest in a promising tech startup becomes available. The fund can invest up to \$75,000 in this option. If they choose to invest, they will receive the invested capital plus 150\% return at the end of the fourth year. (Notice, here you get not 150\% in total but invested capital PLUS 150\% return).
# - Real Estate Fund: This option becomes available from year 3. The fund can invest any amount at the start of 3rd or 4th year, and they will receive 110\% of the invested capital at the end of year 4.
# Real Estate Fund: This option becomes available from year 3. The fund can invest any amount at the start of 3rd or 4th year, and they will receive 110\% of the invested capital at the end of year 4.
# The hedge fund aims to maximize its total payout at the end of the four-year period.

# %% [markdown]
# ### Key Equations / Principles
# - Name: ¶
# - Instructions ¶
# - Problem 1: Multi-Year Investment Strategy ¶
# - Question 1.1: Formulate this as a linear programming problem mathematically (write objective function and constraints in the next cell (below) which is in a markdown mode). ¶
# - Question 1.2: implement and solve this problem computationally. ¶
# - Question 1.3: perform a sensitivity analysis on the interest rates. How would the optimal strategy change if the real estate return increases from 110\% to 180\%? (Explain) ¶
# - Problem 2: Modified Schelling's Segregation Model ¶
# - Question 2.1: initializes all agents with random positions on the unit square and show graphically. ¶
# - Question 2.2: Implement the logic where each agent checks whether they are happy or unhappy and moves if necessary. Run the simulation iteratively until all agents are happy. Track the number of iterations it takes for the system to reach a stable state where no agent wants to move. ¶
# - Question 2.3: Plot the result ¶

# %% [markdown]
# ### Code Examples (Reformatted)
# These are direct from your completed work, cleaned for readability.

# %%
import numpy as np
import pandas as pd

from scipy.optimize import linprog
import matplotlib.pyplot as plt

# %%
# Objective function parameters
c_ex2 = np.array([1.40*4, 0, 0, 0, 1.05, 2.50, 1.1, 1.1])

# equality constraints
A_ex2 = np.array([[1,  1,  0,  0,  0, 0, 0, 0],
                  [1, -1.05, 1, 0, 0, 1, 0, 0],
                  [1, 0, -1.05, 1, 0, 0, 1, 0],
                  [1, 0, 0, -1.05, 1, 0, 0, 1]])
b_ex2 = np.array([150000, 0, 0, 0])

# Bounds on decision variables
bounds_ex2 = [(  0,    None),
              (-25000, None),
              (-25000, None),
              (-25000, None),
              (-25000, None),
              (  0,   75000),
              (0, None),
              (0, None)]

# Solve the problem
res_ex2 = linprog(-c_ex2, A_eq=A_ex2, b_eq=b_ex2, bounds=bounds_ex2, options = {"tol": 1e-14})

res_ex2

# %%
     con: array([-3.49245965e-10,  4.94765118e-10,  7.73070497e-12,  5.45696821e-12])
     fun: -311908.04356022156
 message: 'Optimization terminated successfully.'
     nit: 12
   slack: array([], dtype=float64)
  status: 0
 success: True
       x: array([ 2.69032221e+04,  1.23096778e+05,  2.73483948e+04,  1.81259244e+03,
       -2.50000000e+04,  7.50000000e+04,  3.14018905e-12,  3.54407266e-14])

# %%
# Objective function parameters
c_ex2 = np.array([1.40*4, 0, 0, 0, 1.05, 2.50, 1.8, 1.8])

# equality constraints
A_ex2 = np.array([[1,  1,  0,  0,  0, 0, 0, 0],
                  [1, -1.05, 1, 0, 0, 1, 0, 0],
                  [1, 0, -1.05, 1, 0, 0, 1, 0],
                  [1, 0, 0, -1.05, 1, 0, 0, 1]])
b_ex2 = np.array([150000, 0, 0, 0])

# Bounds on decision variables
bounds_ex2 = [(  0,    None),
              (-25000, None),
              (-25000, None),
              (-25000, None),
              (-25000, None),
              (  0,   75000),
              (0, None),
              (0, None)]

# Solve the problem
res_ex2 = linprog(-c_ex2, A_eq=A_ex2, b_eq=b_ex2, bounds=bounds_ex2, options = {"tol": 1e-14})

res_ex2

# %%
     con: array([-1.27183739e-08,  2.29629222e-08, -4.07453626e-09, -8.58562998e-10])
     fun: -369971.25
 message: 'Optimization terminated successfully.'
     nit: 12
   slack: array([], dtype=float64)
  status: 0
 success: True
       x: array([ 1.36214560e-13,  1.50000000e+05,  8.25000000e+04,  8.66250000e+04,
       -2.50000000e+04,  7.50000000e+04,  5.41368636e-11,  1.15956250e+05])

# %%
# draw randomly all locations
agents = pd.DataFrame(np.random.uniform(0, 1, size = (1000, 2)), columns=['x', 'y'])

# assign type where 0 is oragne, 1 is green and 2 is blue
agents['type']=0
agents.loc[300:500, 'type']=1
agents.loc[500:, 'type']=2

agents.head()

# %% [markdown]
# ### Practice Questions (Variants)
# 1. (a) Explain the principle of **Name: ¶** in Completed.
# 2. (b) Write a Python implementation of Name: ¶ and analyze convergence properties.
# 3. (c) Discuss one scenario where Name: ¶ would fail or require modification.
# 4. (a) Explain the principle of **Instructions ¶** in Completed.
# 5. (b) Write a Python implementation of Instructions ¶ and analyze convergence properties.
# 6. (c) Discuss one scenario where Instructions ¶ would fail or require modification.
# 7. (a) Explain the principle of **Problem 1: Multi-Year Investment Strategy ¶** in Completed.
# 8. (b) Write a Python implementation of Problem 1: Multi-Year Investment Strategy ¶ and analyze convergence properties.
# 9. (c) Discuss one scenario where Problem 1: Multi-Year Investment Strategy ¶ would fail or require modification.
# 10. (a) Explain the principle of **Question 1.1: Formulate this as a linear programming problem mathematically (write objective function and constraints in the next cell (below) which is in a markdown mode). ¶** in Completed.

# %% [markdown]
# ### Worked Answer Sketches
# - **Answer:** Map each question to optimization routine or regression. Include convergence, tolerance, and result validation. Discuss assumptions and possible improvements.

# %% [markdown]
# ## Final Cheat Sheet
#
# **Optimization / Root Finding**
# - Bisection: guaranteed convergence, O(log((b−a)/tol))
# - Newton: fast if f' ≠ 0, quadratic convergence
# - Gradient descent: θ ← θ − η∇f(θ)
#
# **OLS / Linear Algebra**
# - Normal equations: β̂ = (XᵀX)⁻¹Xᵀy
# - Variance of β̂: σ²(XᵀX)⁻¹
# - Use QR/`lstsq` to avoid instability.
#
# **Agent-Based Models**
# - State update: s_{t+1}=(1−α)s_t+ε_t
# - Ensemble mean: μ_t = (1/N)∑ s_{i,t}
# - Sensitivity: simulate α ∈ [0.05, 0.5]
#
# **Discrete Choice / Logit**
# - P_ij = exp(V_ij)/∑_k exp(V_ik)
# - Log-likelihood: ℓ(β) = ∑ y_ij log P_ij(β)
# - IIA: relative odds independent of irrelevant alternatives.
#
# **Coding Tips**
# ```python
# np.linalg.lstsq(X, y, rcond=None)[0]
# from scipy.optimize import minimize
# from scipy.special import softmax
# ```
